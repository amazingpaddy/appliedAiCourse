# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
def function_1(x, option: int):
    if option == 1:
        return (x**2 - 1) / (x - 1)
    elif option == 2:
        return (x**2 - 25) / (x + 5)
    elif option == 3:
        return (x**2 - 2*x - 8) / (x - 4)
    elif option == 4:
        return 25 / x

def plot_graph(x_value, y_value, xlim: tuple, ylim: tuple, xaxvline: int, yaxhline: int):
    fig, ax = plt.subplots()
    plt.xlim(xlim[0], xlim[1])
    plt.ylim(ylim[0], ylim[1])
    plt.axvline(x=xaxvline, color='purple', linestyle='--')
    plt.axhline(y=yaxhline, color='purple', linestyle='--')
    return ax.plot(x_value, y_value)

# %%
x = np.linspace(-10, 10, 10000)

# %% [markdown]
# $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$

# %%
y = function_1(x, 1)
print(function_1(0, option=1))
_ = plot_graph(x, y, (-10, 10), (-2, 4), 0, 1)
# Out:
# 1.0

# %% [markdown]
# $$ \lim_{x \to -5} \frac{x^2-25}{x+5} $$

# %%
y = function_1(x, 2)
print(function_1(-4.999999, option=2))
_ = plot_graph(x, y, (-10, 20), (-20, 20), -5, -10)
# Out:
# -9.9999989999111

# %% [markdown]
# $$ \lim_{x \to 4} \frac{x^2 -2x -8}{x-4} $$

# %%
y = function_1(x, 3)
print(function_1(3.99999999, option=3))
print(function_1(4.001, option=3))
_ = plot_graph(x, y, (-6, 6), (-10, 10), 4, 6)
# Out:
# 6.0
# 6.001000000001028

# %%
def f(x):
    return x ** 2 + 2 * x + 2

y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray', ls='--')
plt.axhline(y=0, color='lightgray', ls='--')
ax.plot(x,y)

# %%
x1 = 2
y1 = f(x1)
y1
# Out:
# 10

# %%
delta_x = 0.000001
x2 = x1 + delta_x  #increase x1 by the value very very close to zero
f(x2) # or we can say f(x1 + deltax)
y2 = f(x1 + delta_x)
y2
# Out:
# 10.000006000001001

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray', ls='--')
plt.axhline(y=0, color='lightgray', ls='--')
plt.scatter(-1, 1)
plt.scatter(-0.9, 1.01, c = 'yellow', zorder=3)
ax.plot(x,y)

# %%
m =  (y2 - y1) / (x2 - x1)
m
# Out:
# 6.000001000088901

# %%
# y = mx + b
# b = y - mx
b = y2 - (m * x2)
b
# Out:
# -2.000002000177801

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray', ls='--')
plt.axhline(y=0, color='lightgray', ls='--')
plt.scatter(x1, y1, c = 'green')
plt.scatter(x2, y2, c = 'yellow', zorder=3)
plt.plot(x, line_y, c='red')
ax.plot(x,y)

# %%
y = f(x)
y
# Out:
# array([ 82.       ,  81.9640004,  81.9280088, ..., 121.9120072,
#        121.9559996, 122.       ])

# %%
x1 = torch.tensor(2.0, requires_grad=True)
y1 = f(x1)
y1
# Out:
# tensor(10., grad_fn=<AddBackward0>)

# %%
y1.backward()
x1.grad
# Out:
# tensor(6.)

# %%
import tensorflow as tf

# %%
x1 = tf.Variable(2.0)

# %%
with tf.GradientTape() as t:
    t.watch(x1)
    y1 = f(x1)

t.gradient(y1, x1)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.0>
